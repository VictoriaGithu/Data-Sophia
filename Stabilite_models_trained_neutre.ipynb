# %% [markdown]
# **Code pour étudier la stabilité des modèles.** \
# Pour des paramètres fixés, 10 modèles sont entraînés qui diffèrent seulement par un shuffle de corpus d'entraînement. Pour chacun de ces modèles, on regarde l'ensemble des 10 mots les plus proches de femmes. On fait ensuite l'intersection de ces 10 modèles. Plus le nombre de mots dans l'intersection est proche de 10, plus le modèle avec les paramètres fixés est stable.

# %% [markdown]
# **Première étude :** _corpus neutre_

# %%
#!/usr/bin/env python3
# coding=utf-8
import sys
from gensim.models import KeyedVectors
from copy import copy
from itertools import product
import os

window_size = [5,10,15,20]
dim_vecteur = [2,4,8,16,32,64,100]
epochs = [5,10,20,30,40,50]
for i, j, k in product(window_size, dim_vecteur, epochs):
    femmes = []
    hommes = []
    for g in range(10):
        ifilename = f"models-trained-003/model_G{g:03d}W{i:03d}V{j:03d}E{k:03d}.wordvec"
        if not os.path.exists(ifilename):
            continue
        wv = KeyedVectors.load(ifilename)
        femmes.append({x[0] for x in wv.most_similar("femme", topn=10)})
        hommes.append({x[0] for x in wv.most_similar("homme", topn=10)})



    if len(femmes) > 0:
        #print(f"W{i:03d}V{j:03d}E{k:03d} "+"="*20+"femme similarity"+"="*20)
        c = copy(femmes[0])
        for x in femmes:
            #print(x)
            c &= x
        print(f"W{i:03d}V{j:03d}E{k:03d} femme={c}")

        

     #print()
    if len(hommes) > 0:
        #print(f"W{i:03d}V{j:03d}E{k:03d} "+"="*20+"homme similarity"+"="*20)

        c = copy(hommes[0])
        for x in hommes:
            #print(x)
            c &= x
        print(f"W{i:03d}V{j:03d}E{k:03d} homme={c}")
# Out:
# W005V002E005 homme=set()
# W005V002E010 homme=set()
# W005V002E020 homme=set()
# W005V002E030 homme=set()
# W005V002E040 homme=set()
# W005V002E050 homme=set()
# W005V004E005 homme=set()
# W005V004E010 homme=set()
# W005V004E020 homme=set()
# W005V004E030 homme=set()
# W005V004E040 homme=set()
# W005V004E050 homme=set()
# W005V008E005 homme=set()
# W005V008E010 homme=set()
# W005V008E020 homme=set()
# W005V008E030 homme=set()
# W005V008E040 homme=set()
# W005V008E050 homme=set()
# W005V016E005 homme={'mal'}
# W005V016E010 homme=set()
# W005V016E020 homme={'vieillard'}
# W005V016E030 homme=set()
# W005V016E040 homme=set()
# W005V016E050 homme=set()
# W005V032E005 homme={'orateur', 'ecolier'}
# W005V032E010 homme={'malade'}
# W005V032E020 homme=set()
# W005V032E030 homme={'vieillard'}
# W005V032E040 homme={'vieillard'}
# W005V032E050 homme=set()
# W005V064E005 homme={'acteur', 'orateur', 'malade'}
# W005V064E010 homme=set()
# W005V064E020 homme={'avare', 'quelqu'}
# W005V064E030 homme={'quelqu'}
# W005V064E040 homme={'vieillard', 'acteur', 'quelqu'}
# W005V064E050 homme={'quelqu'}
# W005V100E005 homme={'sot', 'ecolier', 'ouvrier'}
# W005V100E010 homme={'sot'}
# W005V100E020 homme={'quelqu'}
# W005V100E030 homme={'avare', 'quelqu'}
# W005V100E040 homme={'vieillard', 'garcon', 'avare', 'quelqu'}
# W005V100E050 homme={'vieillard', 'quelqu'}
# W010V002E005 homme=set()
# W010V002E010 homme=set()
# W010V002E020 homme=set()
# W010V002E030 homme=set()
# W010V002E040 homme=set()
# W010V002E050 homme=set()
# W010V004E005 homme={'bon'}
# W010V004E010 homme=set()
# W010V004E020 homme=set()
# W010V004E030 homme={'menace'}
# W010V004E040 homme=set()
# W010V004E050 homme=set()
# W010V008E005 homme=set()
# W010V008E010 homme=set()
# W010V008E020 homme=set()
# W010V008E030 homme=set()
# W010V008E040 homme=set()
# W010V008E050 homme=set()
# W010V016E005 homme={'mal'}
# W010V016E010 homme={'mal'}
# W010V016E020 homme={'mal', 'honnetement'}
# W010V016E030 homme={'mal'}
# W010V016E040 homme={'mal', 'honnetement'}
# W010V016E050 homme={'mal', 'honnetement'}
# W010V032E005 homme={'mal'}
# W010V032E010 homme=set()
# W010V032E020 homme={'mal'}
# W010V032E030 homme={'mal'}
# W010V032E040 homme={'vieillard', 'mal'}
# W010V032E050 homme={'vieillard', 'mal'}
# W010V064E005 homme=set()
# W010V064E010 homme={'historien', 'jaloux'}
# W010V064E020 homme={'vieillard', 'quelqu'}
# W010V064E030 homme={'quelqu'}
# W010V064E040 homme={'quelqu'}
# W010V064E050 homme={'quelqu'}
# W010V100E005 homme={'orateur'}
# W010V100E010 homme={'quelqu'}
# W010V100E020 homme={'avare', 'quelqu'}
# W010V100E030 homme={'quelqu', 'affront'}
# W010V100E040 homme={'il', 'quelqu', 'affront'}
# W010V100E050 homme={'il', 'quelqu', 'affront'}
# W015V002E005 homme=set()
# W015V002E010 homme=set()
# W015V002E020 homme=set()
# W015V002E030 homme=set()
# W015V002E040 homme=set()
# W015V002E050 homme=set()
# W015V004E005 homme={'bien'}
# W015V004E010 homme={'laisse', 'bien'}
# W015V004E020 homme=set()
# W015V004E030 homme={'bien'}
# W015V004E040 homme=set()
# W015V004E050 homme=set()
# W015V008E005 homme=set()
# W015V008E010 homme=set()
# W015V008E020 homme=set()
# W015V008E030 homme={'maltraite'}
# W015V008E040 homme={'maltraite'}
# W015V008E050 homme={'maltraite'}
# W015V016E005 homme={'mal'}
# W015V016E010 homme={'mal'}
# W015V016E020 homme={'mal'}
# W015V016E030 homme={'mal', 'toujours'}
# W015V016E040 homme={'mal', 'toujours', 'honnetement'}
# W015V016E050 homme={'mal', 'toujours', 'honnetement'}
# W015V032E005 homme={'mal'}
# W015V032E010 homme={'mal', 'jaloux'}
# W015V032E020 homme={'mal'}
# W015V032E030 homme={'on'}
# W015V032E040 homme={'vieillard', 'on', 'mal'}
# W015V032E050 homme={'on', 'mal', 'jaloux'}
# W015V064E005 homme={'vieillard'}
# W015V064E010 homme={'quelqu'}
# W015V064E020 homme={'quelqu'}
# W015V064E030 homme={'vieillard', 'historien', 'quelqu'}
# W015V064E040 homme={'proverbialement', 'quelqu'}
# W015V064E050 homme={'quelqu'}
# W015V100E005 homme=set()
# W015V100E010 homme={'vieillard', 'jaloux', 'fou', 'quelqu'}
# W015V100E020 homme={'il', 'quelqu'}
# W015V100E030 homme={'il', 'quelqu'}
# W015V100E040 homme={'vieillard', 'on', 'il', 'quelqu'}
# W015V100E050 homme={'on', 'il', 'quelqu'}
# W020V002E005 homme=set()
# W020V002E010 homme=set()
# W020V002E020 homme=set()
# W020V002E030 homme=set()
# W020V002E040 homme=set()
# W020V002E050 homme=set()
# W020V004E005 homme=set()
# W020V004E010 homme={'mal', 'laisse', 'propos', 'bien'}
# W020V004E020 homme=set()
# W020V004E030 homme={'bien'}
# W020V004E040 homme={'bien'}
# W020V004E050 homme=set()
# W020V008E005 homme=set()
# W020V008E010 homme=set()
# W020V008E020 homme={'maltraite'}
# W020V008E030 homme={'maltraite'}
# W020V008E040 homme={'maltraite'}
# W020V008E050 homme={'maltraite'}
# W020V016E005 homme={'mal', 'diable'}
# W020V016E010 homme={'mal'}
# W020V016E020 homme={'mal', 'toujours'}
# W020V016E030 homme={'mal', 'toujours', 'honnetement'}
# W020V016E040 homme={'mal', 'toujours', 'honnetement'}
# W020V016E050 homme={'mal', 'honnetement'}
# W020V032E005 homme={'mal'}
# W020V032E010 homme={'mal'}
# W020V032E020 homme={'mal'}
# W020V032E030 homme={'mal', 'bien', 'jaloux'}
# W020V032E040 homme={'il'}
# W020V032E050 homme={'on', 'mal'}
# W020V064E005 homme=set()
# W020V064E010 homme={'jaloux', 'quelqu'}
# W020V064E020 homme={'quelqu'}
# W020V064E030 homme={'quelqu'}
# W020V064E040 homme={'vieillard', 'il', 'quelqu'}
# W020V064E050 homme={'il', 'proverbialement', 'quelqu'}
# W020V100E005 homme={'jaloux', 'riche'}
# W020V100E010 homme={'jaloux', 'quelqu'}
# W020V100E020 homme={'vieillard', 'il', 'quelqu'}
# W020V100E030 homme={'on', 'il', 'quelqu'}
# W020V100E040 homme={'on', 'il', 'quelqu'}
# W020V100E050 homme={'on', 'il', 'quelqu'}

# %% [markdown]
# Le modèle entraîné sur corpus neutre le plus stable est donné par la ligne suivante : W010V100E030 femme={'fille', 'semme', 'nourrice', 'princesse', 'veuve', 'coquette', 'maitresse'}. Donc le max est un set de 7 mots et le meilleur modèle a une window_size de 10, des vecteurs de dimension 100 et 30 epochs.

# %% [markdown]
# Le modèle entraîné sur corpus neutre + bible le plus stable est donné par la ligne suivante : W005V100E020 femme={'maitresse', 'veuve', 'concubine', 'princesse', 'servante', 'soeur', 'fille', 'nourrice', 'epouse'}. Donc le max est un set de 9 mots et le meilleur modèle a une window_size de 5, des vecteurs de dimension 100 et 20 epochs.

# %% [markdown]
# _Question_ : c'est quoi le mot 'semme' ??

# %%
def chercher_mot_dans_corpus(mot_a_chercher, corpus):
    occurrences = []

    for i, phrase in enumerate(corpus):
        for j, mot in enumerate(phrase):
            if mot.lower() == mot_a_chercher.lower():
                occurrences.append((i, j))  # Enregistrer l'indice de la phrase et l'indice du mot

    return occurrences

# %%
def afficher_phrases_occurrences(corpus, occurrences):
    for occurrence in occurrences:
        i, j = occurrence
        print(f"Phrase {i + 1}, Mot {j + 1}: {' '.join(corpus[i])}")

# %%
# # Utiliser la fonction chercher_mot_dans_corpus
# mot_a_chercher = 'semme'
# occurrences = chercher_mot_dans_corpus(mot_a_chercher, corpus_neutre)

# # Afficher les phrases correspondantes
# afficher_phrases_occurrences(corpus_neutre, occurrences)

# %% [markdown]
# - Phrase 70241, Mot 3: est une semme tres aimable
# - Phrase 75420, Mot 7: soupirer pour les appas une belle semme
# - Phrase 75944, Mot 2: cette semme est qu une apprentie en intrigue
# - Phrase 87529, Mot 2: cette semme de beaux bijoux
# - Phrase 116710, Mot 13: il plus un an que ce mari ne couche plus avec sa semme
# - Phrase 127281, Mot 12: on dit aussi dans un sens un peu different qu une semme est accouchee mais qu elle est pas entierement delivree pour dire que arriere faix est pas encore venu delivrer signifie aussi livrer mettre entre les mains

# %% [markdown]
# **'Semme' est donc une faute de frappe pour 'femme' ! Ne remet pas en cause la stabilité, mais à changer pour la suite de l'étude.**

# %% [markdown]
# **Deuxième étude** : _corpus neutre ET bible_
